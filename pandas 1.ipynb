# %% [markdown]
# # Pandas

# %%
Employees={'name':['ahmed','richard','omar','ali','maryam'],
       'age':[35,36,28,30,28],
       'department':['operations','operations','marketing','finance','HR'],
           'overtime':[12,15,18,21,18],
      'hobbies':['chess','basketball','chess','football','drawing']}

# %%
import pandas as pd

# %%
df=pd.DataFrame(Employees)

# %%
df
# Out:
#       name  age  department  overtime     hobbies
# 0    ahmed   35  operations        12       chess
# 1  richard   36  operations        15  basketball
# 2     omar   28   marketing        18       chess
# 3      ali   30     finance        21    football
# 4   maryam   28          HR        18     drawing

# %%
# Excel file
# csv file : comma separated 
# Json

# %%
df=pd.read_excel('D:/Data science/cars_excel.xlsx')

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                122  alfa-romero       gas
# 1             1          3                122  alfa-romero       gas
# 2             2          1                122  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 196         200         -1                 95        volvo       gas
# 197         201         -1                 95        volvo       gas
# 198         202         -1                 95        volvo       gas
# 199         203         -1                 95        volvo    diesel
# 200         204         -1                 95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
df1=pd.read_csv('cars_clean.csv')

# %%
df1
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3              122.0  alfa-romero       gas
# 1             1          3              122.0  alfa-romero       gas
# 2             2          1              122.0  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 196         200         -1               95.0        volvo       gas
# 197         201         -1               95.0        volvo       gas
# 198         202         -1               95.0        volvo       gas
# 199         203         -1               95.0        volvo    diesel
# 200         204         -1               95.0        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                122  alfa-romero       gas
# 1             1          3                122  alfa-romero       gas
# 2             2          1                122  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 196         200         -1                 95        volvo       gas
# 197         201         -1                 95        volvo       gas
# 198         202         -1                 95        volvo       gas
# 199         203         -1                 95        volvo    diesel
# 200         204         -1                 95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
pd.set_option('display.max_columns',100)

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                122  alfa-romero       gas
# 1             1          3                122  alfa-romero       gas
# 2             2          1                122  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 196         200         -1                 95        volvo       gas
# 197         201         -1                 95        volvo       gas
# 198         202         -1                 95        volvo       gas
# 199         203         -1                 95        volvo    diesel
# 200         204         -1                 95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
# 2           2          1                122  alfa-romero       gas        std
# 3           3          2                164         audi       gas        std
# 4           4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
#
#   fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        mpfi  3.47    2.68                9.0       111.0    5000.0
# 1        mpfi  3.47    2.68                9.0       111.0    5000.0
#
#    city-mpg  highway-mpg  price
# 0        21           27  13495
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make fuel-type aspiration  \
# 196         200         -1                 95  volvo       gas        std
# 197         201         -1                 95  volvo       gas      turbo
# 198         202         -1                 95  volvo       gas        std
# 199         203         -1                 95  volvo    diesel      turbo
# 200         204         -1                 95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  length  \
# 196         four      sedan          rwd           front       109.1   188.8
# 197         four      sedan          rwd           front       109.1   188.8
# 198         four      sedan          rwd           front       109.1   188.8
# 199         four      sedan          rwd           front       109.1   188.8
# 200         four      sedan          rwd           front       109.1   188.8
#
# ...

# %%
top_10=df.head(10)
top_10
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
# 2           2          1                122  alfa-romero       gas        std
# 3           3          2                164         audi       gas        std
# 4           4          2                164         audi       gas        std
# 5           5          2                122         audi       gas        std
# 6           6          1                158         audi       gas        std
# 7           7          1                122         audi       gas        std
# 8           8          1                158         audi       gas      turbo
# 9          10          2                192          bmw       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0   symboling  normalized-losses  wheel-base      length  \
# count  201.000000  201.000000          201.00000  201.000000  201.000000
# mean   102.900498    0.840796          122.00000   98.797015  174.200995
# std     59.234956    1.254802           31.99625    6.066366   12.322175
# min      0.000000   -2.000000           65.00000   86.600000  141.100000
# 25%     53.000000    0.000000          101.00000   94.500000  166.800000
# 50%    103.000000    1.000000          122.00000   97.000000  173.200000
# 75%    154.000000    2.000000          137.00000  102.400000  183.500000
# max    204.000000    3.000000          256.00000  120.900000  208.100000
#
#             width      height  curb-weight  engine-size        bore  \
# count  201.000000  201.000000   201.000000   201.000000  201.000000
# mean    65.889055   53.766667  2555.666667   126.875622    3.330711
# std      2.101471    2.447822   517.296727    41.546834    0.268072
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['length'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df.head(2)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
#
#   fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        mpfi  3.47    2.68                9.0       111.0    5000.0
# 1        mpfi  3.47    2.68                9.0       111.0    5000.0
#
#    city-mpg  highway-mpg  price
# 0        21           27  13495
# ...

# %%
df.shape
# Out:
# (201, 27)

# %%
dimensions=df[['height','width','length']]
dimensions
# Out:
#      height  width  length
# 0      48.8   64.1   168.8
# 1      48.8   64.1   168.8
# 2      52.4   65.5   171.2
# 3      54.3   66.2   176.6
# 4      54.3   66.4   176.6
# ..      ...    ...     ...
# 196    55.5   68.9   188.8
# 197    55.5   68.8   188.8
# 198    55.5   68.9   188.8
# 199    55.5   68.9   188.8
# 200    55.5   68.9   188.8
#
# [201 rows x 3 columns]

# %%
dimensions.describe()
# Out:
#            height       width      length
# count  201.000000  201.000000  201.000000
# mean    53.766667   65.889055  174.200995
# std      2.447822    2.101471   12.322175
# min     47.800000   60.300000  141.100000
# 25%     52.000000   64.100000  166.800000
# 50%     54.100000   65.500000  173.200000
# 75%     55.500000   66.600000  183.500000
# max     59.800000   72.000000  208.100000

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0   symboling  normalized-losses    make fuel-type  \
# count   201.000000  201.000000          201.00000     201       201
# unique         NaN         NaN                NaN      22         2
# top            NaN         NaN                NaN  toyota       gas
# freq           NaN         NaN                NaN      32       181
# mean    102.900498    0.840796          122.00000     NaN       NaN
# std      59.234956    1.254802           31.99625     NaN       NaN
# min       0.000000   -2.000000           65.00000     NaN       NaN
# 25%      53.000000    0.000000          101.00000     NaN       NaN
# 50%     103.000000    1.000000          122.00000     NaN       NaN
# 75%     154.000000    2.000000          137.00000     NaN       NaN
# max     204.000000    3.000000          256.00000     NaN       NaN
#
#        aspiration num-of-doors body-style drive-wheels engine-location  \
# count         201          201        201          201             201
# ...

# %%
df['make'].value_counts()[0:3]
# Out:
# toyota    32
# nissan    18
# mazda     17
# Name: make, dtype: int64

# %%
df.head(2)
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
#
#   fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        mpfi  3.47    2.68                9.0       111.0    5000.0
# 1        mpfi  3.47    2.68                9.0       111.0    5000.0
#
#    city-mpg  highway-mpg  price
# 0        21           27  13495
# ...

# %%
#loc
#iloc
# slicing

# %%
df.loc[6,'make']
# Out:
# 'audi'

# %%
df.loc[df['make']=='alfa-romero',:]
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
# 2           2          1                122  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
# 2   65.5    52.4         2823        ohcv              six          152
#
# ...

# %%
df.loc[df['make']=='alfa-romero',:].shape
# Out:
# (3, 27)

# %%
df.iloc[:,0:7]
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                122  alfa-romero       gas
# 1             1          3                122  alfa-romero       gas
# 2             2          1                122  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 196         200         -1                 95        volvo       gas
# 197         201         -1                 95        volvo       gas
# 198         202         -1                 95        volvo       gas
# 199         203         -1                 95        volvo    diesel
# 200         204         -1                 95        volvo       gas
#
#     aspiration num-of-doors
# 0          std          two
# 1          std          two
# 2          std          two
# ...

# %%
a=df.columns

# %%
a=list(a)

# %%
a[0]='Unknown'

# %%
a
# Out:
# ['Unknown',
#  'symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
df.columns=a
df
# Out:
#      Unknown  symboling  normalized-losses         make fuel-type aspiration  \
# 0          0          3                122  alfa-romero       gas        std
# 1          1          3                122  alfa-romero       gas        std
# 2          2          1                122  alfa-romero       gas        std
# 3          3          2                164         audi       gas        std
# 4          4          2                164         audi       gas        std
# ..       ...        ...                ...          ...       ...        ...
# 196      200         -1                 95        volvo       gas        std
# 197      201         -1                 95        volvo       gas      turbo
# 198      202         -1                 95        volvo       gas        std
# 199      203         -1                 95        volvo    diesel      turbo
# 200      204         -1                 95        volvo       gas      turbo
#
# ...

# %%
df.loc[df['symboling']> df['symboling'].mean(),:]
# Out:
#      Unknown  symboling  normalized-losses         make fuel-type aspiration  \
# 0          0          3                122  alfa-romero       gas        std
# 1          1          3                122  alfa-romero       gas        std
# 2          2          1                122  alfa-romero       gas        std
# 3          3          2                164         audi       gas        std
# 4          4          2                164         audi       gas        std
# ..       ...        ...                ...          ...       ...        ...
# 182      186          2                 94   volkswagen       gas        std
# 183      187          2                 94   volkswagen    diesel      turbo
# 184      188          2                 94   volkswagen       gas        std
# 185      189          3                122   volkswagen       gas        std
# 186      190          3                256   volkswagen       gas        std
#
# ...

# %%
df['symboling'].mean()
# Out:
# 0.8407960199004975

# %%
df.dtypes
# Out:
# Unknown                int64
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unknown            201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   fuel-type          201 non-null    object
#  5   aspiration         201 non-null    object
#  6   num-of-doors       201 non-null    object
#  7   body-style         201 non-null    object
#  8   drive-wheels       201 non-null    object
#  9   engine-location    201 non-null    object
#  10  wheel-base         201 non-null    float64
#  11  length             201 non-null    float64
#  12  width              201 non-null    float64
#  13  height             201 non-null    float64
#  14  curb-weight        201 non-null    int64
#  15  engine-type        201 non-null    object
# ...

# %%
df['width']=df['width'].astype(str)

# %%
df.dtypes
# Out:
# Unknown                int64
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                 object
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df['width']=df['width'].astype(float)

# %%
df.dtypes
# Out:
# Unknown                int64
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unknown              0
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df['make'].nunique()
# Out:
# 22

# %%
df['length'].max()
# Out:
# 208.1

# %%
df.head(2)
# Out:
#    Unknown  symboling  normalized-losses         make fuel-type aspiration  \
# 0        0          3                122  alfa-romero       gas        std
# 1        1          3                122  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
#
#   fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        mpfi  3.47    2.68                9.0       111.0    5000.0
# 1        mpfi  3.47    2.68                9.0       111.0    5000.0
#
#    city-mpg  highway-mpg  price
# 0        21           27  13495
# ...

# %%
df['dim']=df['width'] * df['height']
df.head(2)
# Out:
#    Unknown  symboling  normalized-losses         make fuel-type aspiration  \
# 0        0          3                122  alfa-romero       gas        std
# 1        1          3                122  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
# 1   64.1    48.8         2548        dohc             four          130
#
#   fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        mpfi  3.47    2.68                9.0       111.0    5000.0
# 1        mpfi  3.47    2.68                9.0       111.0    5000.0
#
#    city-mpg  highway-mpg  price      dim
# ...

# %%
df['dim'].mean()
# Out:
# 3544.201094527359

# %%
|
